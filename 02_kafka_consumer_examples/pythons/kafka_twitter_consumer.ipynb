# %%
from kafka import KafkaConsumer
from pprint import pprint
import json

# %%
TOPIC = "topic_one"

# %%
consumer = KafkaConsumer(TOPIC,
                         bootstrap_servers=["localhost:9092"],
                         group_id="counters"
                        )

# %%
for record in consumer:
    pprint(json.loads(str(record.value.decode("utf-8"))))

# %%
data = {'created_at': 'Sat Apr 11 20:44:44 +0000 2020', 'id': 1249075937888440320, 'id_str': '1249075937888440320', 'text': 'RT @jennycohn1: Woah. Without assistance, the US Postal Service could shutter as early June, opening the door to Trump’s cronies who would…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 14181633, 'id_str': '14181633', 'name': 'proudmari🖐 #HandMarkedPaperBallots', 'screen_name': 'proudmari', 'location': 'California, USA', 'url': None, 'description': 'observing that which goes un-noticed', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 484, 'friends_count': 1482, 'listed_count': 52, 'favourites_count': 23117, 'statuses_count': 17399, 'created_at': 'Thu Mar 20 02:23:03 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '060404', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_link_color': '981CEB', 'profile_sidebar_border_color': 'DFDFDF', 'profile_sidebar_fill_color': '3E3728', 'profile_text_color': 'D16D2E', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/761018535451648004/36LUv3I-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/761018535451648004/36LUv3I-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14181633/1470276245', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Apr 11 20:20:34 +0000 2020', 'id': 1249069853371240451, 'id_str': '1249069853371240451', 'text': 'Woah. Without assistance, the US Postal Service could shutter as early June, opening the door to Trump’s cronies wh… https://t.co/6gTVnDpyk8', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4541535439, 'id_str': '4541535439', 'name': 'Jennifer Cohn ✍🏻', 'screen_name': 'jennycohn1', 'location': None, 'url': 'https://medium.com/@jennycohn1', 'description': 'Election security advocate & writer; attorney; published work in  @WhoWhatWhy @NYRDaily @Salon #HandMarkedPaperBallots #ProtectOurVotes 🆘', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 125440, 'friends_count': 9734, 'listed_count': 965, 'favourites_count': 84113, 'statuses_count': 134757, 'created_at': 'Sat Dec 12 21:59:25 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'E81C4F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1195163578807898112/irRsYABX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1195163578807898112/irRsYABX_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4541535439/1573785542', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1249032058493681664, 'quoted_status_id_str': '1249032058493681664', 'quoted_status': {'created_at': 'Sat Apr 11 17:50:23 +0000 2020', 'id': 1249032058493681664, 'id_str': '1249032058493681664', 'text': 'White House rejects bailout for U.S. Postal Service battered by coronavirus https://t.co/3OYrP3a36Q', 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2467791, 'id_str': '2467791', 'name': 'The Washington Post', 'screen_name': 'washingtonpost', 'location': 'Washington, DC', 'url': 'http://washingtonpost.com', 'description': 'Breaking news, analysis, and opinion. Founded in 1877. Our staff on Twitter: https://twitter.com/washingtonpost/lists/washington-post-people', 'translator_type': 'regular', 'protected': False, 'verified': True, 'followers_count': 15441864, 'friends_count': 1657, 'listed_count': 95774, 'favourites_count': 4445, 'statuses_count': 354993, 'created_at': 'Tue Mar 27 11:19:39 +0000 2007', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '333333', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0057EC', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DBDBDB', 'profile_text_color': '323232', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1060271522319925257/fJKwJ0r2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1060271522319925257/fJKwJ0r2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2467791/1469484132', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 1412, 'reply_count': 903, 'retweet_count': 2204, 'favorite_count': 2078, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/3OYrP3a36Q', 'expanded_url': 'https://wapo.st/2VkBw7j', 'display_url': 'wapo.st/2VkBw7j', 'indices': [76, 99]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en'}, 'quoted_status_permalink': {'url': 'https://t.co/W1VmA7NYkv', 'expanded': 'https://twitter.com/washingtonpost/status/1249032058493681664', 'display': 'twitter.com/washingtonpost…'}, 'is_quote_status': True, 'extended_tweet': {'full_text': 'Woah. Without assistance, the US Postal Service could shutter as early June, opening the door to Trump’s cronies who would presumably privatize it and administer vote by mail in November. 😳 https://t.co/W1VmA7NYkv', 'display_text_range': [0, 189], 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/W1VmA7NYkv', 'expanded_url': 'https://twitter.com/washingtonpost/status/1249032058493681664', 'display_url': 'twitter.com/washingtonpost…', 'indices': [190, 213]}], 'user_mentions': [], 'symbols': []}}, 'quote_count': 29, 'reply_count': 26, 'retweet_count': 255, 'favorite_count': 316, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/6gTVnDpyk8', 'expanded_url': 'https://twitter.com/i/web/status/1249069853371240451', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en'}, 'quoted_status_id': 1249032058493681664, 'quoted_status_id_str': '1249032058493681664', 'quoted_status': {'created_at': 'Sat Apr 11 17:50:23 +0000 2020', 'id': 1249032058493681664, 'id_str': '1249032058493681664', 'text': 'White House rejects bailout for U.S. Postal Service battered by coronavirus https://t.co/3OYrP3a36Q', 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2467791, 'id_str': '2467791', 'name': 'The Washington Post', 'screen_name': 'washingtonpost', 'location': 'Washington, DC', 'url': 'http://washingtonpost.com', 'description': 'Breaking news, analysis, and opinion. Founded in 1877. Our staff on Twitter: https://twitter.com/washingtonpost/lists/washington-post-people', 'translator_type': 'regular', 'protected': False, 'verified': True, 'followers_count': 15441864, 'friends_count': 1657, 'listed_count': 95774, 'favourites_count': 4445, 'statuses_count': 354993, 'created_at': 'Tue Mar 27 11:19:39 +0000 2007', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '333333', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0057EC', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DBDBDB', 'profile_text_color': '323232', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1060271522319925257/fJKwJ0r2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1060271522319925257/fJKwJ0r2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2467791/1469484132', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 1412, 'reply_count': 903, 'retweet_count': 2204, 'favorite_count': 2078, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/3OYrP3a36Q', 'expanded_url': 'https://wapo.st/2VkBw7j', 'display_url': 'wapo.st/2VkBw7j', 'indices': [76, 99]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en'}, 'quoted_status_permalink': {'url': 'https://t.co/W1VmA7NYkv', 'expanded': 'https://twitter.com/washingtonpost/status/1249032058493681664', 'display': 'twitter.com/washingtonpost…'}, 'is_quote_status': True, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'jennycohn1', 'name': 'Jennifer Cohn ✍🏻', 'id': 4541535439, 'id_str': '4541535439', 'indices': [3, 14]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1586637884958'}

# %%
pprint(data)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Apr 11 20:44:44 +0000 2020',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 4541535439,
#                                  'id_str': '4541535439',
#                                  'indices': [3, 14],
#                                  'name': 'Jennifer Cohn ✍🏻',
#                                  'screen_name': 'jennycohn1'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1249075937888440320,
#  'id_str': '1249075937888440320',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'quoted_status': {'contributors': None,
#                    'coordinates': None,
# ...

# %%
[(key, type(key)) for key in data.keys()]
# Out:
# [('created_at', str),
#  ('id', str),
#  ('id_str', str),
#  ('text', str),
#  ('source', str),
#  ('truncated', str),
#  ('in_reply_to_status_id', str),
#  ('in_reply_to_status_id_str', str),
#  ('in_reply_to_user_id', str),
#  ('in_reply_to_user_id_str', str),
#  ('in_reply_to_screen_name', str),
#  ('user', str),
#  ('geo', str),
#  ('coordinates', str),
#  ('place', str),
#  ('contributors', str),
#  ('retweeted_status', str),
#  ('quoted_status_id', str),
#  ('quoted_status_id_str', str),
#  ('quoted_status', str),
#  ('quoted_status_permalink', str),
#  ('is_quote_status', str),
#  ('quote_count', str),
#  ('reply_count', str),
#  ('retweet_count', str),
#  ('favorite_count', str),
#  ('entities', str),
#  ('favorited', str),
#  ('retweeted', str),
#  ('filter_level', str),
#  ('lang', str),
#  ('timestamp_ms', str)]

# %%
"{'created_at': 'Sat Apr 11 20:44:44 +0000 2020', 'id': 1249075937888440320}"
